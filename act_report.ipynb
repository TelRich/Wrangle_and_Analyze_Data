# %% [markdown]
# ## Report: Act_report
#
# ![doggo.jpeg](attachment:doggo.jpeg)
#
# This documentation communicates the insights and displays the visualizations produced from the wrangled data.

# %% [markdown]
# ### Insights
# * What is associated with maximum retweet_count
# * What is associated with maximum favorite_count
# * What is associated with the maximum rating
# * What is the highest confidence score of algorithm 1
#
# Here is the information associated with the first insight.
#
# ![Screenshot%202022-06-06%2015.57.23.png](attachment:Screenshot%202022-06-06%2015.57.23.png)
#
# >The name of the dog with the **maximum retweet count (51,790)** is **Stephan**. Stephan stage is not specified. This dog has a **favorite count of 111,909** and belongs to the dog breed of **Chihuahua** predicted by algorithm 1.

# %% [markdown]
# Information associated with the second insight.
# > There is not much to say here because the same dog, **Stephan**, which had the maximum retweet count has the **maximum favorite count (111,909)**.

# %% [markdown]
# **Findings on the third insights. Meet Cassie**
#
# ![cassie.jpeg](attachment:cassie.jpeg)
#
# > One of the dog with the **highest rating (14)** is **Cassie**. This dog is in its **doggo stage**. Cassie belongs to the cardigan breed of dogs as predicted by algorithm 2 and have a **retweet count** and **favorite count** of **6,110** and **27,990** respectively.

# %% [markdown]
# **The last but not the least insight. Meet Lenox**
#
# ![lenox1.jpeg](attachment:lenox1.jpeg)
#
# > The **highest confidence score of algorithm 1** is **0.999952**. In its prediction, it was able to identify **Lenox** as a dog belonging to the breed of **Barrow**. Lenox has a rating of **10** and is in its **doggo** stage. Also Lenox has a **retweet count** and **favorite count** of **2,318** and **6,559** respectively.

# %% [markdown]
# ### Visualizations
# **Different Dog stage**
#
# ![different_dog_stage-2.png](attachment:different_dog_stage-2.png)
#
# The dog stage was visualized to know which is the most posted. From the chart, we can see that **Pupper** have the highest count. A question came up while looking at the chart, if pupper are the most posted stage of a dog, that means they have the highest retweet count, right? This question led to the next visualization.

# %% [markdown]
# ![Screenshot%202022-06-06%2016.12.36.png](attachment:Screenshot%202022-06-06%2016.12.36.png)

# %% [markdown]
# **Most Retweeted Dog Stage**
#
# ![most_retweeted_dog_stage.png](attachment:most_retweeted_dog_stage.png)
#
# Well, It seems our inference was true. **Pupper** being the most posted dog stage has the highest retweet. Let's look at the most predicted dog breed.

# %% [markdown]
# **15 Most Predicted Dog Breed in Algorithm 1**
#
# ![algorithm_1_prediction.png](attachment:algorithm_1_prediction.png)
#
# The visualization above shows the top 15 dog breeds predicted by algorithm 1 that's being posted on the [WeRateDog](https://twitter.com/dog_rates) twitter account. **Labrador retriever** is the most predicted dog breed followed by **Pembroke**.

# %% [markdown]
# **15 Most Predicted Dog Breed in Algorithm 2**
#
# ![algorithm_2_prediction.png](attachment:algorithm_2_prediction.png)
#
# The visualization above shows the top 15 dog breeds pedicted by algorithm 2. **Labrador retriever** is the most predicted dog breed followed by **Golden retriever**.

# %% [markdown]
# ![Screenshot%202022-06-06%2016.14.10.png](attachment:Screenshot%202022-06-06%2016.14.10.png)

# %% [markdown]
# **15 Most Predicted Dog Breed in Algorithm 3**
#
# ![algorithm_3_prediction.png](attachment:algorithm_3_prediction.png)
#
# The visualization above shows the top 15 dog breeds predicted by algorithm 3. **Labrador retriever** is the most predicted dog breed followed by **Chihuahua**.

# %% [markdown]
# **Relationships:** We will see the relationship between rating, retweet count and favorite count.
#
# **Relationship Between Favorite count and Retweet count**
#
# ![favorite_vs_retweet.png](attachment:favorite_vs_retweet.png)
#
# There is a **positive relationship** between the two. Let's look at rating and retweet count.

# %% [markdown]
# ![Screenshot%202022-06-06%2016.17.44.png](attachment:Screenshot%202022-06-06%2016.17.44.png)

# %% [markdown]
# **Relationship Between Rating and Retweet count**
#
# ![rating_vs_retweet.png](attachment:rating_vs_retweet.png)
#
# The retweet count is **not dependent on the rating** as shown in the plot. The highest rating has less than 10,000 retweet count compared to ratings below 12 which have over 10,000 retweets. Finally, Let's look at rating and favorite count.

# %% [markdown]
# **Relationship Between Rating and Favorite count**
#
# ![rating_vs_favorite.png](attachment:rating_vs_favorite.png)
#
# The above plot is similar to the previous. Probably because favorite count has a positive relationship with retweet count. Regardless, the favorite count of dog tweets is also **not dependent on the rating**. The **highest favorite count** falls between the **rating of 10 to 14**

# %% [markdown]
# The above are the insights and visualization from the project. It is not limited to this as more can be revealed from the wrangled data.
